# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./img/Macc.png" width="auto"/></td>
#         <td>
#             <table><tr>
#             <h1 style="color:blue;text-align:center">Lógica para Ciencias de la Computación</h1></td>
#             </tr></table>
#         <td>&nbsp;</td>
#         <td>
#             <table><tr>
#             <tp><p style="font-size:200%;text-align:center">El Cruce de la gallina</p></tp>
#             <tp><p style="font-size:150%;text-align:center">Grupo 06</p></tp>
#             <tp><p style="font-size:100%;text-align:center">Juliana Contreras, Santiago Jorigua, Simón Vélez</p></tp>
#             <tp><p style="font-size:100%;text-align:center">Universidad del Rosario</p></tp>
#             <tp><p style="font-size:100%;text-align:center">2023</p></tp>
#             </tr></table>
#         </td>
#     </tr>
# </table>
#
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from itertools import combinations, product
from types import MethodType
from Logica import *

# %%
from Problemas import Cruce
from Logica import *

# %%
c = Cruce()

# %%
c.reglas
# Out:
# ['((ĀYĞ)Yļ)',
#  '(-(ġOĿ)=Ą)',
#  '(-(ĤOł)=Ĉ)',
#  '(-(ŅOċ)=Ĩ)',
#  '(-ň=(ĬYč))',
#  '(-į=(ŌYď))',
#  '(-Ē=(ĲYŐ))',
#  '(-(ĵOœ)=Ė)',
#  '(-(ĸOŖ)=Ě)']

# %%
c.OenP.escribir('Ř')
# Out:
# ' Maiz está en la casilla (1) en el tiempo 9'

# %%
print(c.reglas[4])
# Out:
# (-ň=(ĬYč))

# %%
A = inorder_to_tree(c.reglas[0])
print(A.ver(c.OenP))
# Out:
# (( Gallina está en la casilla (0) en el tiempo 0 Y  Zorro está en la casilla (0) en el tiempo 0) Y  Maiz está en la casilla (0) en el tiempo 0)

# %%
A = inorder_to_tree(c.reglas[1])
print(A.ver(c.OenP))
# Out:
# ( no ( Zorro está en la casilla (0) en el tiempo 1 O  Maiz está en la casilla (0) en el tiempo 1) sii  Gallina está en la casilla (1) en el tiempo 1)

# %%
A = inorder_to_tree(c.reglas[2])
print(A.ver(c.OenP))
# Out:
# ( no ( Zorro está en la casilla (0) en el tiempo 2 O  Maiz está en la casilla (0) en el tiempo 2) sii  Gallina está en la casilla (2) en el tiempo 2)

# %%
A = inorder_to_tree(c.reglas[3])
print(A.ver(c.OenP))
# Out:
# ( no ( Maiz está en la casilla (0) en el tiempo 3 O  Gallina está en la casilla (2) en el tiempo 3) sii  Zorro está en la casilla (1) en el tiempo 3)

# %%
A = inorder_to_tree(c.reglas[4])
print(A.ver(c.OenP))
# Out:
# ( no  Maiz está en la casilla (0) en el tiempo 4 sii ( Zorro está en la casilla (2) en el tiempo 4 Y  Gallina está en la casilla (1) en el tiempo 4))

# %%
A = inorder_to_tree(c.reglas[5])
print(A.ver(c.OenP))
# Out:
# ( no  Zorro está en la casilla (2) en el tiempo 5 sii ( Maiz está en la casilla (1) en el tiempo 5 Y  Gallina está en la casilla (0) en el tiempo 5))

# %%
A = inorder_to_tree(c.reglas[6])
print(A.ver(c.OenP))
# Out:
# ( no  Gallina está en la casilla (0) en el tiempo 6 sii ( Zorro está en la casilla (2) en el tiempo 6 Y  Maiz está en la casilla (2) en el tiempo 6))

# %%
A = inorder_to_tree(c.reglas[7])
print(A.ver(c.OenP))
# Out:
# ( no ( Zorro está en la casilla (2) en el tiempo 7 O  Maiz está en la casilla (2) en el tiempo 7) sii  Gallina está en la casilla (1) en el tiempo 7)

# %%
A = inorder_to_tree(c.reglas[8])
print(A.ver(c.OenP))
# Out:
# ( no ( Zorro está en la casilla (2) en el tiempo 8 O  Maiz está en la casilla (2) en el tiempo 8) sii  Gallina está en la casilla (2) en el tiempo 8)

# %%
a = {c.OenP.P([0, 0, 0]),c.OenP.P([0, 0, 1]),c.OenP.P([0, 0, 2]),c.OenP.P([2,1,0]),c.OenP.P([2, 1, 1]),c.OenP.P([2, 1, 2])}
c.visualizar(a)

# %%
# %%time
A = inorder_to_tree(c.reglas[0])
I = A.SATtabla()
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 0 ns

# %%
if I != None:
    for k in I:
        print(c.OenP.escribir(k), I[k])
else:
    print('¡No hay solución!')
# Out:
#  Zorro está en la casilla (0) en el tiempo 0 True
#  Gallina está en la casilla (0) en el tiempo 0 True
#  Maiz está en la casilla (0) en el tiempo 0 True

# %%
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')

# %%
# %%time
A = inorder_to_tree(c.reglas[1])
I = A.SATtabla()
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 279 ms

# %%
# %%time
A = inorder_to_tree(c.reglas[2])
I = A.SATtabla()
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 256 ms

# %%
# %%time
A = inorder_to_tree(c.reglas[3])
I = A.SATtabla()
if I != None:
    c.visualizar(I)
    
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 289 ms

# %%
# %%time
A = inorder_to_tree(c.reglas[4])
I = A.SATtabla()
if I != None:
    c.visualizar(I)
    
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 269 ms

# %%
# %%time
A = inorder_to_tree(c.reglas[5])
I= A.SATtabla()
if I != None:
    c.visualizar(I)
    
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 261 ms

# %%
# %%time
A = inorder_to_tree(c.reglas[6])
I = A.SATtabla()
if I != None:
    c.visualizar(I)
    
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 320 ms

# %%
# %%time
A = inorder_to_tree(c.reglas[7])
I = A.SATtabla()
if I != None:
    c.visualizar(I)
    
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 269 ms

# %%
# %%time
A = inorder_to_tree(c.reglas[8])
I = A.SATtabla()
if I != None:
    c.visualizar(I)
    
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 265 ms

# %%
# %%time
A = inorder_to_tree(Ytoria(c.reglas))
I = A.SATtabla()
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File <timed exec>:2
#
# File /drive/notebooks/prueba/Logica.py:57, in Formula.SATtabla(self)
#      55 letras = list(self.letras())
#      56 n = len(letras)
# ---> 57 valores = list(product([True, False], repeat=n))
#      58 for v in valores:
#      59     I = {letras[x]: v[x] for x in range(n)}
#
# MemoryError:

# %%
# %%time
A = c.reglas[0]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x01': True, '\x00': True, 'Ā': True, 'Ğ': True, 'ļ': True}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 605 ms

# %%
# %%time
A = c.reglas[1]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x02': True, '\x01': False, 'ġ': False, 'Ŀ': False, 'Ą': False, '(': True, '\x00': False}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 577 ms

# %%
# %%time
A = c.reglas[2]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x02': True, '\x01': True, 'Ĉ': True, '(': True, '\x00': False, 'Ĥ': True}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 554 ms

# %%
# %%time
A = c.reglas[3]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x02': True, 'Ņ': True, '\x01': True, 'Ĩ': True, '(': False, '\x00': True}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 559 ms

# %%
# %%time
A = c.reglas[4]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x02': True, '\x01': False, '\x00': False, 'ň': True, 'Ĭ': False}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 556 ms

# %%
# %%time
A = c.reglas[5]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x02': True, 'į': False, '\x00': True, '\x01': True, 'Ō': True, 'ď': True}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 579 ms

# %%
# %%time
A = c.reglas[6]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x02': True, '\x01': True, 'Ĳ': True, 'Ő': True, '\x00': True, 'Ē': False}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 576 ms

# %%
# %%time
A = c.reglas[7]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x02': True, 'ĵ': False, '\x01': False, 'œ': False, 'Ė': False, '\x00': True, '(': False}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 570 ms

# %%
# %%time
A = c.reglas[8]
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'\x02': True, '\x01': False, 'ĸ': False, 'Ŗ': False, 'Ě': False, '\x00': False, '(': True}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 573 ms

# %%
# %%time
A = Ytoria(c.reglas)
S = tseitin(A)
S, I = dpll(S, {})
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'!': True, '\x1d': True, '\x19': True, '\x15': True, '\x11': True, '\r': True, '\t': True, '\x05': True, '\x01': True, '\x00': True, 'Ā': True, 'Ğ': True, 'ļ': True, '\x04': True, '\x08': True, '\x0c': True, '\x10': True, '\x14': True, '\x18': True, '\x1c': True, ' ': True, 'Ē': True, '\x16': False, '\x17': False, 'Ŀ': False, '\x1a': False, '(': True, '\x02': False, '\x06': False, '\n': False, '\x1e': False, '\x03': True, 'ġ': True, 'Ą': True, '\x0e': True, 'ň': False, '\x0f': True, 'Ĭ': True, 'č': True, '\x1b': True, 'Ė': True, '\x07': True, 'Ĉ': True, 'ď': False, '\x13': False, '\x12': False, 'į': True, 'ċ': True, '\x0b': True, 'Ĩ': True, '\x1f': True, 'Ě': True, 'Ő': False, 'Ŗ': True, 'œ': True, 'Ĥ': True}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 674 ms

# %%
# %%time
S= c.reglas[0]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 261 ms

# %%
# %%time
S= c.reglas[1]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 288 ms

# %%
# %%time
S= c.reglas[2]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 272 ms

# %%
# %%time
S= c.reglas[3]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 273 ms

# %%
# %%time
S= c.reglas[4]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 269 ms

# %%
# %%time
S= c.reglas[5]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 262 ms

# %%
# %%time
S= c.reglas[6]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 258 ms

# %%
# %%time
S= c.reglas[7]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 269 ms

# %%
# %%time
S= c.reglas[8]
S, I = walkSAT(S)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 296 ms

# %%
# %%time
A = Ytoria(c.reglas)
A, I = walkSAT(A)
print(I)
if I != None:
    c.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# {'ň': True, 'Ĳ': True, 'ď': True, 'ġ': True, 'ċ': True, 'ļ': True, 'Ŗ': True, 'ĸ': True, 'Ő': True, 'Ņ': True, 'į': True, 'Ą': True, 'Ā': True, 'O': True, 'ĵ': True, 'Y': True, 'Ĉ': True, 'Ĥ': True, ')': True, '(': True, '-': True, 'Ė': True, 'Ŀ': True, '=': True, 'Ĭ': True, 'œ': True, 'Ĩ': True, 'Ē': True, 'Ğ': True, 'ł': True, 'č': True, 'Ě': True, 'Ō': True}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 467 ms
